# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1 = pd.read_csv('reviews_0-250_masked.csv')
data1.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0  rating  is_recommended  helpfulness  \
# 0             0           0       5             1.0          1.0
# 1             1           1       1             0.0          NaN
# 2             2           2       5             1.0          NaN
#
#    total_feedback_count  total_neg_feedback_count  total_pos_feedback_count  \
# 0                     2                         0                         2
# 1                     0                         0                         0
# 2                     0                         0                         0
#
#   submission_time                                        review_text  \
# 0      2023-02-01  I use this with the Nudestix “Citrus Clean Bal...
# 1      2023-03-21  I bought this lip mask after reading the revie...
# 2      2023-03-21  My review title says it all! I get so excited ...
#
#                        review_title skin_tone eye_color skin_type hair_color  \
# 0  Taught me how to double cleanse!       NaN     brown       dry      black
# 1                      Disappointed       NaN       NaN       NaN        NaN
# 2              New Favorite Routine     light     brown       dry     blonde
#
#   product_id                                       product_name brand_name  \
# 0    P504322                     Gentle Hydra-Gel Face Cleanser   NUDESTIX
# 1    P420652  Lip Sleeping Mask Intense Hydration with Vitam...    LANEIGE
# 2    P420652  Lip Sleeping Mask Intense Hydration with Vitam...    LANEIGE
#
#    price_usd
# 0       19.0
# 1       24.0
# 2       24.0

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168432 entries, 0 to 168431
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Unnamed: 0.1              168432 non-null  int64
#  1   Unnamed: 0                168432 non-null  int64
#  2   rating                    168432 non-null  int64
#  3   is_recommended            127179 non-null  float64
#  4   helpfulness               70138 non-null   float64
#  5   total_feedback_count      168432 non-null  int64
#  6   total_neg_feedback_count  168432 non-null  int64
#  7   total_pos_feedback_count  168432 non-null  int64
#  8   submission_time           168432 non-null  object
#  9   review_text               168209 non-null  object
#  10  review_title              122599 non-null  object
#  11  skin_tone                 132082 non-null  object
#  12  eye_color                 121531 non-null  object
#  13  skin_type                 144055 non-null  object
#  14  hair_color                121079 non-null  object
#  15  product_id                168432 non-null  object
#  16  product_name              168432 non-null  object
#  17  brand_name                168432 non-null  object
#  18  price_usd                 168432 non-null  float64
# dtypes: float64(3), int64(6), object(10)
# memory usage: 24.4+ MB

# %%
data1.isna().sum()
# Out:
# Unnamed: 0.1                    0
# Unnamed: 0                      0
# rating                          0
# is_recommended              41253
# helpfulness                 98294
# total_feedback_count            0
# total_neg_feedback_count        0
# total_pos_feedback_count        0
# submission_time                 0
# review_text                   223
# review_title                45833
# skin_tone                   36350
# eye_color                   46901
# skin_type                   24377
# hair_color                  47353
# product_id                      0
# product_name                    0
# brand_name                      0
# price_usd                       0
# dtype: int64

# %%
data2 = pd.read_csv('reviews_1250-end_masked.csv')
data2.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0  rating  is_recommended  helpfulness  \
# 0           416         416       2             0.0     0.125000
# 1           417         417       5             1.0     0.857143
# 2           418         418       4             1.0     1.000000
#
#    total_feedback_count  total_neg_feedback_count  total_pos_feedback_count  \
# 0                     8                         7                         1
# 1                    14                         2                        12
# 2                     1                         0                         1
#
#   submission_time                                        review_text  \
# 0      2023-02-27  I used it once a day for a month and saw no vi...
# 1      2023-02-04  I got really bad cystic acne, once the acne we...
# 2      2022-12-05  Really pleased with this serum so far although...
#
#                                 review_title    skin_tone eye_color  \
# 0        I wanted so badly for this to work.          NaN      blue
# 1  Every morning and night. Follow with spf!  lightMedium     brown
# 2                                        NaN        light     brown
#
#      skin_type hair_color product_id                         product_name  \
# 0          dry     blonde    P473126  CLINICAL Discoloration Repair Serum
# 1  combination      black    P473126  CLINICAL Discoloration Repair Serum
# 2  combination        NaN    P473126  CLINICAL Discoloration Repair Serum
#
#        brand_name  price_usd
# 0  Paula's Choice       52.0
# 1  Paula's Choice       52.0
# 2  Paula's Choice       52.0

# %%
data2.isna().sum()
# Out:
# Unnamed: 0.1                   0
# Unnamed: 0                     0
# rating                         0
# is_recommended               856
# helpfulness                 2978
# total_feedback_count           0
# total_neg_feedback_count       0
# total_pos_feedback_count       0
# submission_time                0
# review_text                   22
# review_title                3263
# skin_tone                   1407
# eye_color                   1360
# skin_type                    834
# hair_color                  1703
# product_id                     0
# product_name                   0
# brand_name                     0
# price_usd                      0
# dtype: int64

# %%
data3 = pd.read_csv('reviews_250-500_masked.csv')
data3.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0  rating  is_recommended  helpfulness  \
# 0          2281        2281       1             0.0         0.75
# 1          2282        2282       5             1.0         1.00
# 2          2283        2283       5             1.0          NaN
#
#    total_feedback_count  total_neg_feedback_count  total_pos_feedback_count  \
# 0                     4                         1                         3
# 1                     1                         0                         1
# 2                     0                         0                         0
#
#   submission_time                                        review_text  \
# 0      2023-03-12  I really wanted to love this mask, but it brok...
# 1      2023-03-07  Seen results after just one use! Use as a nigh...
# 2      2023-02-20  No matter I use on my face in my night routine...
#
#                                 review_title skin_tone eye_color    skin_type  \
# 0                       Did not work for me.       NaN     brown  combination
# 1                      Must have for redness     light     green  combination
# 2  Emphasis on the calming and complimentary      deep     brown  combination
#
#   hair_color product_id                                  product_name  \
# 0        NaN    P479841  Floral Recovery Overnight Mask with Squalane
# 1        red    P479841  Floral Recovery Overnight Mask with Squalane
# 2      black    P479841  Floral Recovery Overnight Mask with Squalane
#
#   brand_name  price_usd
# 0      fresh       69.0
# 1      fresh       69.0
# 2      fresh       69.0

# %%
data3.isna().sum()
# Out:
# Unnamed: 0.1                    0
# Unnamed: 0                      0
# rating                          0
# is_recommended               8913
# helpfulness                 28520
# total_feedback_count            0
# total_neg_feedback_count        0
# total_pos_feedback_count        0
# submission_time                 0
# review_text                    36
# review_title                14751
# skin_tone                    9241
# eye_color                   10845
# skin_type                    6041
# hair_color                  11728
# product_id                      0
# product_name                    0
# brand_name                      0
# price_usd                       0
# dtype: int64

# %%
data4 = pd.read_csv('reviews_500-750_masked.csv')
data4.isna().sum()
# Out:
# Unnamed: 0.1                    0
# Unnamed: 0                      0
# rating                          0
# is_recommended               3684
# helpfulness                 13472
# total_feedback_count            0
# total_neg_feedback_count        0
# total_pos_feedback_count        0
# submission_time                 0
# review_text                    48
# review_title                 8577
# skin_tone                    4540
# eye_color                    4831
# skin_type                    3446
# hair_color                   5538
# product_id                      0
# product_name                    0
# brand_name                      0
# price_usd                       0
# dtype: int64

# %%
data5 = pd.read_csv('reviews_750-1250_masked.csv')
data5.isna().sum()
# Out:
# Unnamed: 0.1                    0
# Unnamed: 0                      0
# rating                          0
# is_recommended               2526
# helpfulness                 11058
# total_feedback_count            0
# total_neg_feedback_count        0
# total_pos_feedback_count        0
# submission_time                 0
# review_text                    16
# review_title                 7270
# skin_tone                    3688
# eye_color                    3809
# skin_type                    2176
# hair_color                   4759
# product_id                      0
# product_name                    0
# brand_name                      0
# price_usd                       0
# dtype: int64

# %%
data5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25040 entries, 0 to 25039
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0.1              25040 non-null  int64
#  1   Unnamed: 0                25040 non-null  int64
#  2   rating                    25040 non-null  int64
#  3   is_recommended            22514 non-null  float64
#  4   helpfulness               13982 non-null  float64
#  5   total_feedback_count      25040 non-null  int64
#  6   total_neg_feedback_count  25040 non-null  int64
#  7   total_pos_feedback_count  25040 non-null  int64
#  8   submission_time           25040 non-null  object
#  9   review_text               25024 non-null  object
#  10  review_title              17770 non-null  object
#  11  skin_tone                 21352 non-null  object
#  12  eye_color                 21231 non-null  object
#  13  skin_type                 22864 non-null  object
#  14  hair_color                20281 non-null  object
#  15  product_id                25040 non-null  object
#  16  product_name              25040 non-null  object
#  17  brand_name                25040 non-null  object
#  18  price_usd                 25040 non-null  float64
# dtypes: float64(3), int64(6), object(10)
# memory usage: 3.6+ MB

# %%
data = pd.concat([data1, data2, data3, data4, data5])
data.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0  rating  is_recommended  helpfulness  \
# 0             0           0       5             1.0          1.0
# 1             1           1       1             0.0          NaN
# 2             2           2       5             1.0          NaN
#
#    total_feedback_count  total_neg_feedback_count  total_pos_feedback_count  \
# 0                     2                         0                         2
# 1                     0                         0                         0
# 2                     0                         0                         0
#
#   submission_time                                        review_text  \
# 0      2023-02-01  I use this with the Nudestix “Citrus Clean Bal...
# 1      2023-03-21  I bought this lip mask after reading the revie...
# 2      2023-03-21  My review title says it all! I get so excited ...
#
#                        review_title skin_tone eye_color skin_type hair_color  \
# 0  Taught me how to double cleanse!       NaN     brown       dry      black
# 1                      Disappointed       NaN       NaN       NaN        NaN
# 2              New Favorite Routine     light     brown       dry     blonde
#
#   product_id                                       product_name brand_name  \
# 0    P504322                     Gentle Hydra-Gel Face Cleanser   NUDESTIX
# 1    P420652  Lip Sleeping Mask Intense Hydration with Vitam...    LANEIGE
# 2    P420652  Lip Sleeping Mask Intense Hydration with Vitam...    LANEIGE
#
#    price_usd
# 0       19.0
# 1       24.0
# 2       24.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 285412 entries, 0 to 25039
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Unnamed: 0.1              285412 non-null  int64
#  1   Unnamed: 0                285412 non-null  int64
#  2   rating                    285412 non-null  int64
#  3   is_recommended            228180 non-null  float64
#  4   helpfulness               131090 non-null  float64
#  5   total_feedback_count      285412 non-null  int64
#  6   total_neg_feedback_count  285412 non-null  int64
#  7   total_pos_feedback_count  285412 non-null  int64
#  8   submission_time           285412 non-null  object
#  9   review_text               285067 non-null  object
#  10  review_title              205718 non-null  object
#  11  skin_tone                 230186 non-null  object
#  12  eye_color                 217666 non-null  object
#  13  skin_type                 248538 non-null  object
#  14  hair_color                214331 non-null  object
#  15  product_id                285412 non-null  object
#  16  product_name              285412 non-null  object
#  17  brand_name                285412 non-null  object
#  18  price_usd                 285412 non-null  float64
# dtypes: float64(3), int64(6), object(10)
# memory usage: 43.6+ MB

# %%
data.drop(columns=['Unnamed: 0.1', 'Unnamed: 0', 'helpfulness', 'submission_time'], axis=1, inplace=True)

# %%
data.isna().sum()
# Out:
# rating                          0
# is_recommended              57232
# total_feedback_count            0
# total_neg_feedback_count        0
# total_pos_feedback_count        0
# review_text                   345
# review_title                79694
# skin_tone                   55226
# eye_color                   67746
# skin_type                   36874
# hair_color                  71081
# product_id                      0
# product_name                    0
# brand_name                      0
# price_usd                       0
# dtype: int64

# %%
missing_perc = data.isna().sum()/ len(data) * 100
missing_perc
# Out:
# rating                       0.000000
# is_recommended              20.052415
# total_feedback_count         0.000000
# total_neg_feedback_count     0.000000
# total_pos_feedback_count     0.000000
# review_text                  0.120878
# review_title                27.922442
# skin_tone                   19.349572
# eye_color                   23.736213
# skin_type                   12.919569
# hair_color                  24.904699
# product_id                   0.000000
# product_name                 0.000000
# brand_name                   0.000000
# price_usd                    0.000000
# dtype: float64

# %% [markdown]
# ### Univariate

# %%
#top 20 brands
data['brand_name'].value_counts().head(20)
# Out:
# brand_name
# CLINIQUE               23123
# LANEIGE                18107
# First Aid Beauty       16889
# Youth To The People    16777
# fresh                  16757
# Tatcha                 15863
# Origins                14026
# Peter Thomas Roth      12820
# Summer Fridays         11597
# Estée Lauder           10403
# OLEHENRIKSEN            9657
# Murad                   8849
# Drunk Elephant          8355
# KORRES                  7892
# Glow Recipe             5346
# Dr. Jart+               5070
# Dermalogica             4488
# Biossance               4260
# Farmacy                 4232
# SEPHORA COLLECTION      3924
# Name: count, dtype: int64

# %%
brands = data['brand_name'].value_counts().head(20).index.tolist()
brands_values = data['brand_name'].value_counts().head(20).values.tolist()

plt.barh(brands, brands_values)
plt.xlabel('Count')
plt.ylabel('Brands')
plt.title('Top 20 popular Brands')
plt.show();

# %%
data['skin_tone'].value_counts()
# Out:
# skin_tone
# light          66047
# fair           52619
# lightMedium    47941
# medium         17770
# mediumTan      15341
# fairLight      13958
# tan             8562
# deep            5181
# rich            1435
# porcelain        606
# olive            528
# dark             176
# notSureST         19
# ebony              3
# Name: count, dtype: int64

# %%
data['skin_type'].value_counts()
# Out:
# skin_type
# combination    138772
# dry             45595
# oily            32309
# normal          31862
# Name: count, dtype: int64

# %%
sns.countplot(data=data, x='rating');

# %%
plt.hist(data['price_usd'], bins=50);

# %%
sns.histplot(data=data, x='price_usd');

# %% [markdown]
# ### Bivariate

# %%
data['total_feedback_count'].value_counts()
# Out:
# total_feedback_count
# 0      154322
# 1       34687
# 2       21507
# 3       14875
# 4       10970
#         ...
# 496         1
# 178         1
# 304         1
# 187         1
# 213         1
# Name: count, Length: 341, dtype: int64

# %%
#skin type vs total feedback count
sns.barplot(data=data, x='total_feedback_count', hue='skin_type');

# %%
#brand name vs price
top20 = data.groupby('brand_name')['price_usd'].mean().nlargest(20).reset_index()

sns.barplot(data=top20, x='brand_name', y='price_usd')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
#top 20nmost expensive brands
data.groupby('price_usd')['brand_name'].apply(list).tail(20)
# Out:
# price_usd
# 99.00      [StriVectin, StriVectin, StriVectin, StriVecti...
# 100.00     [La Mer, La Mer, La Mer, La Mer, La Mer, La Me...
# 110.00     [Shiseido, Shiseido, Shiseido, Shiseido, Shise...
# 112.00     [Tatcha, Tatcha, Tatcha, Tatcha, Tatcha, Tatch...
# 115.00     [Estée Lauder, Estée Lauder, Estée Lauder, Est...
# 125.00     [Dr. Barbara Sturm, Dr. Barbara Sturm, Dr. Bar...
# 130.00     [Tata Harper, Tata Harper, Tata Harper, Tata H...
# 140.00     [Kate Somerville, Kate Somerville, Kate Somerv...
# 145.00     [SK-II, SK-II, SK-II, SK-II, SK-II, SK-II, SK-...
# 150.00     [Dr. Barbara Sturm, Dr. Barbara Sturm, Dr. Bar...
# 169.99     [PROVEN Skincare, PROVEN Skincare, PROVEN Skin...
# 170.00     [SK-II, SK-II, SK-II, SK-II, SK-II, SK-II, SK-...
# 190.00     [La Mer, La Mer, La Mer, La Mer, La Mer, La Me...
# 195.00     [Estée Lauder, Estée Lauder, Estée Lauder, Est...
# 200.00     [La Mer, La Mer, La Mer, La Mer, La Mer, La Me...
# 215.00     [Augustinus Bader, Augustinus Bader, Augustinu...
# 235.00                                            [GUERLAIN]
# 249.00     [BeautyBio, BeautyBio, BeautyBio, BeautyBio, B...
# 300.00     [La Mer, La Mer, La Mer, La Mer, La Mer, La Me...
# 1900.00    [Shani Darden Skin Care, Shani Darden Skin Car...
# Name: brand_name, dtype: object

# %%
top_brands_expe = data.groupby(['brand_name'])['price_usd'].agg(['mean']).sort_values(by='mean', ascending=False)
top_brands_expe.head(20)
# Out:
#                                mean
# brand_name
# Shani Darden Skin Care  1900.000000
# GUERLAIN                 235.000000
# La Mer                   202.453532
# PROVEN Skincare          169.990000
# SK-II                    100.663842
# Estée Lauder              98.729597
# Dr. Barbara Sturm         92.256637
# Augustinus Bader          85.128726
# MACRENE actives           85.000000
# StriVectin                81.413793
# Tata Harper               76.968560
# SOBEL SKIN Rx             75.000000
# Shiseido                  71.788489
# ROSE INC                  70.000000
# Saint Jane Beauty         66.233766
# Bobbi Brown               63.600000
# Hourglass                 61.678082
# Mount Lai                 60.000000
# HUM Nutrition             60.000000
# Dr. Zenovia Skincare      57.968196

# %% [markdown]
# ### Multivariate

# %%
#feedback counts
tot_feedback = data['total_feedback_count'].sum()
tot_neg_feedback = data['total_neg_feedback_count'].sum()
tot_pos_feedback = data['total_pos_feedback_count'].sum()

feedback = ['Total feedback', 'Tot Negative feedback', 'Tot positive feedback']
total_feedbacks = [tot_feedback, tot_neg_feedback, tot_pos_feedback]

plt.barh(feedback, total_feedbacks)
plt.xlabel('Count')
plt.title('Feedback Count');

# %%
#correlation
data.corr(numeric_only=True)
# Out:
#                             rating  is_recommended  total_feedback_count  \
# rating                    1.000000        0.841999             -0.080190
# is_recommended            0.841999        1.000000             -0.078691
# total_feedback_count     -0.080190       -0.078691              1.000000
# total_neg_feedback_count -0.172323       -0.159538              0.577722
# total_pos_feedback_count -0.046669       -0.049604              0.978549
# price_usd                -0.019505        0.001747              0.014715
#
#                           total_neg_feedback_count  total_pos_feedback_count  \
# rating                                   -0.172323                 -0.046669
# is_recommended                           -0.159538                 -0.049604
# total_feedback_count                      0.577722                  0.978549
# total_neg_feedback_count                  1.000000                  0.397174
# total_pos_feedback_count                  0.397174                  1.000000
# price_usd                                 0.008021                  0.014520
#
#                           price_usd
# rating                    -0.019505
# is_recommended             0.001747
# total_feedback_count       0.014715
# total_neg_feedback_count   0.008021
# total_pos_feedback_count   0.014520
# price_usd                  1.000000

# %%
plt.figure(figsize=(18,12))
sns.heatmap(data.corr(numeric_only=True), annot=True)
plt.show()

# %% [markdown]
# ### Data cleaning

# %% [markdown]
# ### Lowercasing

# %%
data['lowercase text'] = data['review_text'].str.lower()
data[['review_text', 'lowercase text']].head(3)
# Out:
#                                          review_text  \
# 0  I use this with the Nudestix “Citrus Clean Bal...
# 1  I bought this lip mask after reading the revie...
# 2  My review title says it all! I get so excited ...
#
#                                       lowercase text
# 0  i use this with the nudestix “citrus clean bal...
# 1  i bought this lip mask after reading the revie...
# 2  my review title says it all! i get so excited ...

# %% [markdown]
# ### Remove noise

# %%
# !pip install contractions
import re
import string
import contractions

def clean_text(text):
    if not isinstance(text, str):
        return text
    text = contractions.fix(text) #expand contractions.eg, can't to cannot
    text = re.sub(r'[^\w\s]', '', text) #remove punctuation
    text = re.sub(r'\d+', '', text) #remove digits
    text = re.sub(r'\s+', ' ', text).strip() #remove extra spaces
    return text

#apply the function to lowercase text column
data['lowercase text'] = data['lowercase text'].apply(clean_text)

#display 5 rows
data[['review_text', 'lowercase text']].head()
# Out:
# Collecting contractions
#   Downloading contractions-0.1.73-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting textsearch>=0.0.21 (from contractions)
#   Downloading textsearch-0.0.24-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting anyascii (from textsearch>=0.0.21->contractions)
#   Downloading anyascii-0.3.2-py3-none-any.whl.metadata (1.5 kB)
# Collecting pyahocorasick (from textsearch>=0.0.21->contractions)
#   Downloading pyahocorasick-2.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Downloading contractions-0.1.73-py2.py3-none-any.whl (8.7 kB)
# Downloading textsearch-0.0.24-py2.py3-none-any.whl (7.6 kB)
# Downloading anyascii-0.3.2-py3-none-any.whl (289 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.9/289.9 kB 11.5 MB/s eta 0:00:00
# Downloading pyahocorasick-2.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.3/118.3 kB 10.7 MB/s eta 0:00:00
# Installing collected packages: pyahocorasick, anyascii, textsearch, contractions
# Successfully installed anyascii-0.3.2 contractions-0.1.73 pyahocorasick-2.1.0 textsearch-0.0.24
#                                          review_text  \
# 0  I use this with the Nudestix “Citrus Clean Bal...
# 1  I bought this lip mask after reading the revie...
# 2  My review title says it all! I get so excited ...
# 3  I’ve always loved this formula for a long time...
# 4  If you have dry cracked lips, this is a must h...
#
#                                       lowercase text
# 0  i use this with the nudestix citrus clean balm...
# 1  i bought this lip mask after reading the revie...
# 2  my review title says it all i get so excited t...
# 3  i have always loved this formula for a long ti...
# 4  if you have dry cracked lips this is a must ha...

# %% [markdown]
# ### Tokenization

# %%
import nltk
nltk.download('punkt_tab')
data['tokenized text'] = data['lowercase text'].astype(str).apply(nltk.word_tokenize)

#display 5 rows
data[['lowercase text', 'tokenized text']].head()
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
#                                       lowercase text  \
# 0  i use this with the nudestix citrus clean balm...
# 1  i bought this lip mask after reading the revie...
# 2  my review title says it all i get so excited t...
# 3  i have always loved this formula for a long ti...
# 4  if you have dry cracked lips this is a must ha...
#
#                                       tokenized text
# 0  [i, use, this, with, the, nudestix, citrus, cl...
# 1  [i, bought, this, lip, mask, after, reading, t...
# 2  [my, review, title, says, it, all, i, get, so,...
# 3  [i, have, always, loved, this, formula, for, a...
# 4  [if, you, have, dry, cracked, lips, this, is, ...

# %% [markdown]
# ### Stopword removal

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

#remove stopwords
data['clean text'] = data['tokenized text'].apply(lambda tokens: [word for word in tokens if word not in stop_words])

#display 5 rows to compare if stopwords have been removed
data[['tokenized text', 'clean text']].head()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
#                                       tokenized text  \
# 0  [i, use, this, with, the, nudestix, citrus, cl...
# 1  [i, bought, this, lip, mask, after, reading, t...
# 2  [my, review, title, says, it, all, i, get, so,...
# 3  [i, have, always, loved, this, formula, for, a...
# 4  [if, you, have, dry, cracked, lips, this, is, ...
#
#                                           clean text
# 0  [use, nudestix, citrus, clean, balm, makeup, m...
# 1  [bought, lip, mask, reading, reviews, hype, un...
# 2  [review, title, says, get, excited, get, bed, ...
# 3  [always, loved, formula, long, time, honestly,...
# 4  [dry, cracked, lips, must, weeks, use, learned...

# %% [markdown]
# ### Lemmatization

# %%
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

#apply lemmatization
data['Lemmatized text'] = data['clean text'].apply(lambda tokens: [lemmatizer.lemmatize(word) for word in tokens])

#compare
data[['clean text', 'Lemmatized text']].head()
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
#                                           clean text  \
# 0  [use, nudestix, citrus, clean, balm, makeup, m...
# 1  [bought, lip, mask, reading, reviews, hype, un...
# 2  [review, title, says, get, excited, get, bed, ...
# 3  [always, loved, formula, long, time, honestly,...
# 4  [dry, cracked, lips, must, weeks, use, learned...
#
#                                      Lemmatized text
# 0  [use, nudestix, citrus, clean, balm, makeup, m...
# 1  [bought, lip, mask, reading, review, hype, unf...
# 2  [review, title, say, get, excited, get, bed, a...
# 3  [always, loved, formula, long, time, honestly,...
# 4  [dry, cracked, lip, must, week, use, learned, ...

# %%
from wordcloud import WordCloud

# %%
all_words = [word for sublist in data['Lemmatized text'] for word in sublist]
all_text = " ".join(all_words)

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_text)
plt.figure(figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
#create a new column
data['Sentiment'] = data['rating'].apply(lambda x: 'Positive' if x> 3 else 'Negative' if x<3 else 'Neutral')

# %%
 #sentiment class distribution
sentiment = data['Sentiment'].value_counts().index.tolist()
sentiment_values = data['Sentiment'].value_counts().values.tolist()

plt.figure(figsize=(10,8))
plt.bar(sentiment, sentiment_values)
plt.xlabel('Sentiment')
plt.ylabel('Sentiment count')
plt.title('Sentiment distribution')
plt.show()

# %%
positive = data[data['Sentiment'] == 'Positive']
negative = data[data['Sentiment'] == 'Negative']
nuetral = data[data['Sentiment'] == 'Neutral']

# %%
#word cloud for positive sentiments

#drop missing values
positive.dropna(subset=['review_title'], inplace=True)
#ensuring that review title is string
positive['review_title'] = positive['review_title'].astype(str)
pos_text = " ".join(title for title in positive.review_title)

pos_wordcloud = WordCloud(width=800, height=400, background_color='white').generate(pos_text)
plt.figure(figsize=(15,10))
plt.imshow(pos_wordcloud, interpolation='bicubic')
plt.axis('off')
plt.show();
# Out:
# <ipython-input-47-7a889a439deb>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   positive.dropna(subset=['review_title'], inplace=True)
# <ipython-input-47-7a889a439deb>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   positive['review_title'] = positive['review_title'].astype(str)

# %%
#word cloud for negative sentiments

#drop missing values
negative.dropna(subset=['review_title'], inplace=True)

#ensuring that review title is string
negative['review_title'] = negative['review_title'].astype(str)

#join all texts in review title to one string
neg_text = " ".join(title for title in negative.review_title)

#create word cloud
neg_wordcloud = WordCloud(width=800, height=400,background_color='white').generate(neg_text)
plt.figure(figsize=(15,10))
plt.imshow(neg_wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show();
# Out:
# <ipython-input-48-41ef5e9415e2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negative.dropna(subset=['review_title'], inplace=True)
# <ipython-input-48-41ef5e9415e2>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negative['review_title'] = negative['review_title'].astype(str)
